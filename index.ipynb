# %% [markdown]
# # More Practice With SQL Queries - Lab
#
# ## Introduction
#
# In this lesson, we'll run through some practice questions to refresh our knowledge of SQL Queries!
#
# ## Objectives
#
# You will be able to:
# - Practice your SQL knowledge
#
#
# ## Getting Started
#
# As in previous labs, we'll make use of the `sqlite3` library as well as `pandas`. By combining them, we'll be able to write our queries as python strings, and make sure that the results are always returned as a pandas DataFrame.
#
# We'll start by loading both libraries and connecting to the database we'll be using for this lab, `data.sqlite`. You may remember this database from a previous lab. As a refresher, here's the ERD diagram for this database:
#
# <img src='images/Database-Schema.png'>
#
# In the cell below:
#
# * Import the necessary libraries `pandas` and `sqlite3`
# * Establish a connection to the database `data.sqlite`
# * Get the `cursor` from the connection and store it in the variable `c`.

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
c = conn.cursor()

# %% [markdown]
# ## Basic Queries
#
# Now, let's review basic SQL queries. In the cell below:
#
# * Write a query that gets the first name, last name, phone number, and address for all customers in California with a credit limit greater than 25000.00.

# %%
sql_1 = """

SELECT * FROM sqlite_master WHERE type="table"

"""


c.execute(sql_1)
df_master = pd.DataFrame(c.fetchall())
df_master.columns = [x[0] for x in c.description]
df_master


field_dict = {}

for tab_name in df_master.name:
    sql_2 = """

    SELECT * FROM {}

    """.format(tab_name)
    c.execute(sql_2)
    field_dict.update({tab_name: [x[0] for x in c.description]})

    
print("table names: {}".format(list(field_dict.keys())))
print("\n")

for tab_name in field_dict.keys():
    print("""columns in table "{}": {}\n""".format(tab_name, field_dict[tab_name]))

# %%
# For the first query, the boilerplate for getting 
#the query into a dataframe has been provided for you

sql_str = """

SELECT contactFirstName, contactLastName, phone, addressLine1, CAST(c.creditLimit as DECIMAL(9, 2)) as credLimit
FROM customers c
WHERE credLimit > 25000

"""


c.execute(sql_str)
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    contactFirstName contactLastName               phone  \
# 0              Jean            King          7025551838
# 1             Peter        Ferguson        03 9520 4555
# 2           Janine          Labrune          40.67.8555
# 3            Jonas       Bergulfsen          07-98 9555
# 4             Susan          Nelson          4155551450
# 5            Roland          Keitel   +49 69 66 90 2555
# 6             Julie          Murphy          6505555787
# 7              Kwai             Lee          2125557818
# 8            Diego           Freyre      (91) 555 94 44
# 9        Christina         Berglund        0921-12 3555
# 10           Jytte         Petersen          31 12 3555
# 11            Mary          Saveley          78.32.5555
# 12             Eric       Natividad        +65 221 7555
# 13             Jeff           Young          2125557413
# 14           Kelvin           Leong          2155551555
# 15             Juri       Hashimoto          6505556809
# 16            Wendy       Victorino        +65 224 1555
# 17           Veysel          Oeztan       +47 2267 3215
# 18         Martine            Rancé          20.16.1555
# 19            Marie        Bertrand      (1) 42.34.2555
# 20            Jerry           Tseng          6175555555
# 21            Julie            King          2035552570
# 22             Mory         Kentary    +81 06 6342 5555
# 23          Michael           Frick          2125551500
# 24            Matti       Karttunen         90-224 8555
# 25           Rachel        Ashworth      (171) 555-1555
# 26             Dean         Cassidy      +353 1862 1555
# 27        Elizabeth           Devon      (171) 555-2282
# 28           Yoshi           Tamuri      (604) 555-3392
# 29           Miguel         Barajas          6175557555
# ..              ...             ...                 ...
# 64            Paul          Henriot          26.47.1555
# 65            Wales       MacKinlay        64-9-3763555
# 66             Juri         Yoshido          6175559555
# 67          Dorothy           Young          6035558647
# 68            Allen          Nelson          6175558555
# 69           Georg            Pipps           6562-9555
# 70           Arnold            Cruz      +63 2 555 3587
# 71        Maurizio           Moroni         0522-556555
# 72            Akiko       Shimamura     +81 3 3584 0555
# 73        Dominique         Perrier      (1) 47.55.6555
# 74            Sarah           McRoy         04 499 9555
# 75          Michael     Donnermeyer   +49 89 61 08 9555
# 76            Maria       Hernandez          2125558493
# 77              Dan           Lewis          2035554407
# 78           Martha         Larsson        0695-34 6555
# 79              Sue           Frick          4085553659
# 80          Roland           Mendel           7675-3555
# 81           Leslie          Murphy          2035559545
# 82               Yu            Choi          2125551957
# 83          Martín           Sommer      (91) 555 22 82
# 84          Violeta         Benitez          5085552555
# 85             Sean        Clenahan      61-9-3844-6555
# 86           Franco         Ricotti       +39 022515555
# 87            Steve        Thompson          3105553722
# 88      José Pedro             Roel      (95) 555 82 82
# 89             Rosa         Salazar          2155559857
# 90              Sue          Taylor          4155554312
# 91          Thomas            Smith      (171) 555-7555
# 92          Valarie          Franco          6175552555
# 93             Tony         Snowden       +64 9 5555500
#
#                     addressLine1  credLimit
# 0                8489 Strong St.      71800
# 1              636 St Kilda Road     117300
# 2   67, rue des Cinquante Otages     118200
# 3         Erling Skakkes gate 78      81700
# 4                5677 Strong St.     210500
# 5                  Lyonerstr. 34      59700
# 6      5557 North Pendale Street      64600
# 7        897 Long Airport Avenue     114900
# 8             C/ Moralzarzal, 86     227600
# 9                Berguvsvägen  8      53100
# 10                  Vinbæltet 34      83400
# 11            2, rue du Commerce     123900
# 12                    Bronz Sok.     103800
# 13             4092 Furth Circle     138500
# 14              7586 Pompton St.     100600
# 15             9408 Furth Circle      84600
# 16       106 Linden Road Sandown      97900
# 17               Brehmen St. 121      96800
# 18      184, chaussée de Tournai      82900
# 19       265, boulevard Charonne      84300
# 20                4658 Baden Av.      43400
# 21           25593 South Bay Ln.      84300
# 22                 1-6-20 Dojima      81200
# 23             2678 Kingston Rd.      76400
# 24                 Keskuskatu 45      96500
# 25             Fauntleroy Circus     136800
# 26                25 Maiden Lane      69400
# 27     12, Berkeley Gardens Blvd      92700
# 28                  1900 Oak St.      90300
# 29            7635 Spinnaker Dr.      68700
# ..                           ...        ...
# 64            59 rue de l'Abbaye      81100
# 65          199 Great North Road      77700
# 66            8616 Spinnaker Dr.      41900
# 67      2304 Long Airport Avenue     114200
# 68              7825 Douglas Av.      70700
# 69                   Geislweg 14      71700
# 70            15 McCallum Street      81500
# 71        Strada Provinciale 124     121400
# 72                2-2-8 Roppongi      94400
# 73             25, rue Lauriston      95000
# 74              101 Lambton Quay      86800
# 75                  Hansastr. 15      77000
# 76              5905 Pompton St.      67500
# 77              2440 Pompton St.      49700
# 78                  Åkergatan 24     116400
# 79                3086 Ingle Ln.      77600
# 80                  Kirchgasse 6      45300
# 81      567 North Pendale Street      95400
# 82     5290 North Pendale Street      39800
# 83                C/ Araquil, 67     104600
# 84             1785 First Street      85800
# 85                7 Allen Street      60300
# 86         20093 Cologno Monzese      34800
# 87             3675 Furth Circle      55400
# 88                 C/ Romero, 33      65700
# 89             11328 Douglas Av.      72600
# 90             2793 Furth Circle      60300
# 91               120 Hanover Sq.      43300
# 92                6251 Ingle Ln.      85100
# 93            Arenales 1938 3'A'     110000
#
# [94 rows x 5 columns]

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-1.png'>
#
# ## Aggregate Functions and GROUP BY
#
# Next, write a query that get sthe average credit limit per state.

# %%
sql_str = """

SELECT state, AVG(c.creditLimit) as stateCreditLimit
FROM customers c
GROUP BY state

"""


c.execute(sql_str)
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#             state  stateCreditLimit
# 0                      61839.726027
# 1              BC      89950.000000
# 2              CA      83854.545455
# 3              CT      57350.000000
# 4        Co. Cork          0.000000
# 5   Isle of Wight      93900.000000
# 6              MA      70755.555556
# 7              NH     114200.000000
# 8              NJ      43000.000000
# 9             NSW     100550.000000
# 10             NV      71800.000000
# 11             NY      89966.666667
# 12          Osaka      81200.000000
# 13             PA      84766.666667
# 14       Pretoria          0.000000
# 15     Queensland      51600.000000
# 16         Québec      48700.000000
# 17          Tokyo      94400.000000
# 18       Victoria      88800.000000

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-2.png'>
#
# ## JOINs
#
# Now, write a query that uses JOIN statements to get the customer name, customer number, order number, status, and quantity ordered. Print only the head of this DataFrame.

# %%
sql_str = """

SELECT c.customerName, c.customerNumber, o.orderNumber, o.status, od.quantityOrdered
FROM customers c
JOIN orders o USING(customerNumber)
JOIN orderdetails od USING(orderNumber)


"""


c.execute(sql_str)
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#         customerName customerNumber orderNumber   status quantityOrdered
# 0  Atelier graphique            103       10123  Shipped              26
# 1  Atelier graphique            103       10123  Shipped              34
# 2  Atelier graphique            103       10123  Shipped              46
# 3  Atelier graphique            103       10123  Shipped              50
# 4  Atelier graphique            103       10298  Shipped              32

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-3.png'>
#
# ## HAVING and ORDER BY
#
# Now, repeat the last query, but only get orders from customers that have a quantityOrdered value greater than 30. Sort the rows in ascending order by the quantity ordered.
#
# **_Hint_**: For this one, you'll need to make use of HAVING, GROUP BY, and ORDER BY--make sure you get the order of them correct!

# %%
# get customers that have a quantity ordered value of greater than 30

sql_1 = """

                        SELECT od.orderNumber
                        FROM orderdetails od
                        WHERE quantityOrdered > 30

"""


sql_2 = """

SELECT c.customerName, o.customerNumber, o.orderNumber, o.status, quantityOrdered
FROM orders o
JOIN orderdetails od USING(orderNumber)
JOIN customers c USING(customerNumber)
WHERE o.orderNumber in ({})
ORDER BY cast(quantityOrdered as DECIMAL(9,2)) ASC


""".format(sql_1)



print(sql_2)
c.execute(sql_2)
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
# SELECT c.customerName, o.customerNumber, o.orderNumber, o.status, quantityOrdered
# FROM orders o
# JOIN orderdetails od USING(orderNumber)
# JOIN customers c USING(customerNumber)
# WHERE o.orderNumber in (
#
#                         SELECT od.orderNumber
#                         FROM orderdetails od
#                         WHERE quantityOrdered > 30
#
# )
# ORDER BY cast(quantityOrdered as DECIMAL(9,2)) ASC
#                        customerName customerNumber orderNumber      status  \
# 0         The Sharp Gifts Warehouse            450       10407     On Hold
# 1                  Handji Gifts& Co            166       10409     Shipped
# 2     Extreme Desk Decorations, Ltd            412       10418     Shipped
# 3             Salzburg Collectables            382       10419     Shipped
# 4                        Petit Auto            314       10423  In Process
# 5           Tekni Collectables Inc.            328       10401     On Hold
# 6                 La Rochelle Gifts            119       10425  In Process
# 7             Salzburg Collectables            382       10419     Shipped
# 8         The Sharp Gifts Warehouse            450       10407     On Hold
# 9           Tokyo Collectables, Ltd            398       10408     Shipped
# 10              L'ordine Souveniers            386       10416     Shipped
# 11            Salzburg Collectables            382       10419     Shipped
# 12        Souveniers And Things Co.            282       10420  In Process
# 13    Extreme Desk Decorations, Ltd            412       10418     Shipped
# 14     Australian Collectables, Ltd            471       10415    Disputed
# 15              L'ordine Souveniers            386       10416     Shipped
# 16                La Rochelle Gifts            119       10425  In Process
# 17           Euro+ Shopping Channel            141       10412     Shipped
# 18                La Rochelle Gifts            119       10425  In Process
# 19                Land of Toys Inc.            131       10107     Shipped
# 20                   AV Stores, Co.            187       10110     Shipped
# 21            Salzburg Collectables            382       10119     Shipped
# 22             Marseille Mini Autos            350       10122     Shipped
# 23               Muscle Machine Inc            151       10127     Shipped
# 24               Muscle Machine Inc            151       10127     Shipped
# 25                  Lyon Souveniers            250       10134     Shipped
# 26     Mini Gifts Distributors Ltd.            124       10135     Shipped
# 27        Souveniers And Things Co.            282       10139     Shipped
# 28        Souveniers And Things Co.            282       10139     Shipped
# 29              Suominen Souveniers            334       10141     Shipped
# ...                             ...            ...         ...         ...
# 2966      The Sharp Gifts Warehouse            450       10407     On Hold
# 2967      The Sharp Gifts Warehouse            450       10407     On Hold
# 2968         Euro+ Shopping Channel            141       10412     Shipped
# 2969              Gifts4AllAges.com            362       10414     On Hold
# 2970      Souveniers And Things Co.            282       10420  In Process
# 2971                    Mini Caravy            209       10405     Shipped
# 2972       Danish Wholesale Imports            145       10406    Disputed
# 2973               Handji Gifts& Co            166       10409     Shipped
# 2974        Tekni Collectables Inc.            328       10401     On Hold
# 2975      The Sharp Gifts Warehouse            450       10400     Shipped
# 2976        Tekni Collectables Inc.            328       10401     On Hold
# 2977     Down Under Souveniers, Inc            323       10404     Shipped
# 2978      The Sharp Gifts Warehouse            450       10407     On Hold
# 2979       Danish Wholesale Imports            145       10406    Disputed
# 2980                GiftsForHim.com            357       10410     Shipped
# 2981          UK Collectables, Ltd.            201       10403     Shipped
# 2982          UK Collectables, Ltd.            201       10403     Shipped
# 2983      The Sharp Gifts Warehouse            450       10407     On Hold
# 2984         Euro+ Shopping Channel            141       10417    Disputed
# 2985      Souveniers And Things Co.            282       10420  In Process
# 2986         Euro+ Shopping Channel            141       10412     Shipped
# 2987          Salzburg Collectables            382       10419     Shipped
# 2988                    Mini Caravy            209       10405     Shipped
# 2989      The Sharp Gifts Warehouse            450       10407     On Hold
# 2990      The Sharp Gifts Warehouse            450       10407     On Hold
# 2991        Tekni Collectables Inc.            328       10401     On Hold
# 2992     Down Under Souveniers, Inc            323       10404     Shipped
# 2993        Tekni Collectables Inc.            328       10401     On Hold
# 2994     Down Under Souveniers, Inc            323       10404     Shipped
# 2995                    Mini Caravy            209       10405     Shipped
#
#      quantityOrdered
# 0                  6
# 1                  6
# 2                 10
# 3                 10
# 4                 10
# 5                 11
# 6                 11
# 7                 12
# 8                 13
# 9                 15
# 10                15
# 11                15
# 12                15
# 13                16
# 14                18
# 15                18
# 16                18
# 17                19
# 18                19
# 19                20
# 20                20
# 21                20
# 22                20
# 23                20
# 24                20
# 25                20
# 26                20
# 27                20
# 28                20
# 29                20
# ...              ...
# 2966              59
# 2967              59
# 2968              60
# 2969              60
# 2970              60
# 2971              61
# 2972              61
# 2973              61
# 2974              62
# 2975              64
# 2976              64
# 2977              64
# 2978              64
# 2979              65
# 2980              65
# 2981              66
# 2982              66
# 2983              66
# 2984              66
# 2985              66
# 2986              70
# 2987              70
# 2988              76
# 2989              76
# 2990              76
# 2991              77
# 2992              77
# 2993              85
# 2994              90
# 2995              97
#
# [2996 rows x 5 columns]

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-4.png'>
#
# ## Subqueries
#
# Finally, get the first name, last name, employee number, and office code for employees from an office with less than 5 employees.

# %%
sql_1 = """

SELECT officeCode
FROM employees e
GROUP BY officeCode
HAVING count(employeeNumber)<5

"""

sql_2 = """

SELECT firstName, lastName, employeeNumber, officeCode
FROM employees e
WHERE officeCode in ({})

""".format(sql_1)


c.execute(sql_2)
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    firstName   lastName employeeNumber officeCode
# 0    William  Patterson           1088          6
# 1      Julie   Firrelli           1188          2
# 2      Steve  Patterson           1216          2
# 3   Foon Yue      Tseng           1286          3
# 4     George     Vanauf           1323          3
# 5      Larry       Bott           1501          7
# 6      Barry      Jones           1504          7
# 7       Andy     Fixter           1611          6
# 8      Peter      Marsh           1612          6
# 9        Tom       King           1619          6
# 10      Mami      Nishi           1621          5
# 11   Yoshimi       Kato           1625          5

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-5.png'>
#
# # Summary
#
# In this lesson, we reviewed all the major concepts and keywords associated with SQL queries!
